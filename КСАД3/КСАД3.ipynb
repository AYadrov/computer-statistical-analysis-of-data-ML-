# %% [markdown]
# ### Подключение библиотек, которые понадобятся для обучения сети

# %%
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import LSTM
from keras.utils import to_categorical
from keras.layers import SimpleRNN
from keras.layers import GRU
from keras.layers import Bidirectional

from sklearn.model_selection import GridSearchCV

from keras.wrappers.scikit_learn import KerasClassifier

from matplotlib import pyplot

# %% [markdown]
# ### Создание функций для единовременного извлечения датасета из различных txt файлов

# %%
# load a single file as a numpy array
def load_file(filepath):
    dataframe = read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values

# %%
# load a list of files and return as a 3d numpy array
def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    # stack group so that features are the 3rd dimension
    loaded = dstack(loaded)
    return loaded

# %%
 # load a dataset group, such as train or test
def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    # load all 9 files as a single array
    filenames = list()
    # total acceleration
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    # body acceleration
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    # body gyroscope
    filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    # load input data
    X = load_group(filenames, filepath)
    # load class output
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y

# %%
# load the dataset, returns train and test X and y elements
def load_dataset(prefix=''):
    # load all train
    trainX, trainy = load_dataset_group('train', prefix + 'HARDataset/')
    print(trainX.shape, trainy.shape)
    # load all test
    testX, testy = load_dataset_group('test', prefix + 'HARDataset/')
    print(testX.shape, testy.shape)
    # zero-offset class values
    trainy = trainy - 1
    testy = testy - 1
    # one hot encode y
    trainy = to_categorical(trainy)
    testy = to_categorical(testy)
    print(trainX.shape, trainy.shape, testX.shape, testy.shape)
    return trainX, trainy, testX, testy

# %% [markdown]
# ### Загрузка датасета

# %%
trainX, trainy, testX, testy = load_dataset()
# Out:
# (7352, 128, 9) (7352, 1)
# (2947, 128, 9) (2947, 1)
# (7352, 128, 9) (7352, 6) (2947, 128, 9) (2947, 6)

# %% [markdown]
# Формирование валидационной выборки в соотношении 2:6 к тренировочной

# %%
validX = trainX[:1838]
validy = trainy[:1838]

trainX = trainX[1838:]
trainy = trainy[1838:]

# %% [markdown]
# ### Функция эксперимета, в которой будет происходить подбор гиперпараметров

# %%
def experiment(model, param_grid):
    grid = GridSearchCV(estimator=model, param_grid=param_grid)
    grid_result = grid.fit(validX, validy)

    print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
    means = grid_result.cv_results_['mean_test_score']
    stds = grid_result.cv_results_['std_test_score']
    params = grid_result.cv_results_['params']
    for mean, stdev, param in zip(means, stds, params):
        print("%f (%f) with: %r" % (mean, stdev, param))

# %% [markdown]
# ### Подбор гиперпараметров (layers_count, nerouns_count, optimizer)на основе валидационной выборки для каждой модели (SimpleRNN, LSTM, GRU)

# %% [markdown]
# SimpleRNN

# %%
def create_SimpleRNN(neurons_count=100, layers_count=1, activation='relu', optimizer='SGD'):
    
    n_timesteps, n_features, n_outputs = validX.shape[1], validX.shape[2], validy.shape[1]
    model = Sequential()
    # Входной слой
    model.add(SimpleRNN(100, input_shape=(n_timesteps,n_features)))
    # Скрытый слой
    for _ in range (layers_count):
        model.add(Dense(neurons_count, activation=activation))
    # Выходной слой
    model.add(Dense(n_outputs, activation=activation))
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn=create_SimpleRNN, epochs=1, batch_size=100, verbose=0)

layers_count = [1, 2, 3, 4, 5]
neurons_count = [40, 60, 80, 100, 120]
optimizer = ['SGD']
activation = ['relu']


param_grid = dict(neurons_count=neurons_count, 
                  layers_count=layers_count, 
                  activation=activation, 
                  optimizer=optimizer)

experiment(model, param_grid)
# Out:
# Best: 0.381954 using {'activation': 'relu', 'layers_count': 2, 'neurons_count': 100, 'optimizer': 'SGD'}
# 0.303519 (0.118598) with: {'activation': 'relu', 'layers_count': 1, 'neurons_count': 40, 'optimizer': 'SGD'}
# 0.245344 (0.133964) with: {'activation': 'relu', 'layers_count': 1, 'neurons_count': 60, 'optimizer': 'SGD'}
# 0.225164 (0.090571) with: {'activation': 'relu', 'layers_count': 1, 'neurons_count': 80, 'optimizer': 'SGD'}
# 0.365636 (0.035603) with: {'activation': 'relu', 'layers_count': 1, 'neurons_count': 100, 'optimizer': 'SGD'}
# 0.196886 (0.123149) with: {'activation': 'relu', 'layers_count': 1, 'neurons_count': 120, 'optimizer': 'SGD'}
# 0.327070 (0.112536) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 40, 'optimizer': 'SGD'}
# 0.301885 (0.127649) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 60, 'optimizer': 'SGD'}
# 0.200164 (0.065380) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 80, 'optimizer': 'SGD'}
# 0.381954 (0.132856) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 100, 'optimizer': 'SGD'}
# 0.355315 (0.087517) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 120, 'optimizer': 'SGD'}
# 0.294410 (0.071131) with: {'activation': 'relu', 'layers_count': 3, 'neurons_count': 40, 'optimizer': 'SGD'}
# 0.306423 (0.196980) with: {'activation': 'relu', 'layers_count': 3, 'neurons_count': 60, 'optimizer': 'SGD'}
# 0.294414 (0.128890) with: {'activation': 'relu', 'layers_count': 3, 'neurons_count': 80, 'optimizer': 'SGD'}
# 0.228530 (0.048649) with: {'activation': 'relu', 'layers_count': 3, 'neurons_count': 100, 'optimizer': 'SGD'}
# 0.229004 (0.050300) with: {'activation': 'relu', 'layers_count': 3, 'neurons_count': 120, 'optimizer': 'SGD'}
# 0.201285 (0.038423) with: {'activation': 'relu', 'layers_count': 4, 'neurons_count': 40, 'optimizer': 'SGD'}
# 0.225246 (0.094926) with: {'activation': 'relu', 'layers_count': 4, 'neurons_count': 60, 'optimizer': 'SGD'}
# 0.142556 (0.040801) with: {'activation': 'relu', 'layers_count': 4, 'neurons_count': 80, 'optimizer': 'SGD'}
# 0.362451 (0.124134) with: {'activation': 'relu', 'layers_count': 4, 'neurons_count': 100, 'optimizer': 'SGD'}
# 0.342905 (0.133536) with: {'activation': 'relu', 'layers_count': 4, 'neurons_count': 120, 'optimizer': 'SGD'}
# 0.236121 (0.069457) with: {'activation': 'relu', 'layers_count': 5, 'neurons_count': 40, 'optimizer': 'SGD'}
# 0.222465 (0.076147) with: {'activation': 'relu', 'layers_count': 5, 'neurons_count': 60, 'optimizer': 'SGD'}
# 0.249186 (0.144973) with: {'activation': 'relu', 'layers_count': 5, 'neurons_count': 80, 'optimizer': 'SGD'}
# 0.301382 (0.083228) with: {'activation': 'relu', 'layers_count': 5, 'neurons_count': 100, 'optimizer': 'SGD'}
# 0.233850 (0.108850) with: {'activation': 'relu', 'layers_count': 5, 'neurons_count': 120, 'optimizer': 'SGD'}

# %%
model = KerasClassifier(build_fn=create_SimpleRNN, epochs=1, batch_size=100, verbose=0)

layers_count = [2]
neurons_count = [100]
optimizer = ['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam', 'Adamax', 'Nadam']
activation = ['relu']

param_grid = dict(neurons_count=neurons_count, 
                  layers_count=layers_count, 
                  activation=activation, 
                  optimizer=optimizer)

experiment(model, param_grid)
# Out:
# Best: 0.384560 using {'activation': 'relu', 'layers_count': 2, 'neurons_count': 100, 'optimizer': 'Nadam'}
# 0.278541 (0.113183) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 100, 'optimizer': 'SGD'}
# 0.313360 (0.104754) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 100, 'optimizer': 'RMSprop'}
# 0.317796 (0.074516) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 100, 'optimizer': 'Adagrad'}
# 0.185498 (0.049525) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 100, 'optimizer': 'Adadelta'}
# 0.330826 (0.126667) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 100, 'optimizer': 'Adam'}
# 0.287313 (0.106092) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 100, 'optimizer': 'Adamax'}
# 0.384560 (0.131613) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 100, 'optimizer': 'Nadam'}

# %% [markdown]
# ### Simple RNN. Лучший вариант гиперпараметров: 2 скрытых слоя, 100 нейронов на них, алгоритм оптимизации - Nadam

# %% [markdown]
# LSTM

# %%
def create_LSTM(neurons_count=100, layers_count=1, activation='relu', optimizer='SGD'):
    n_timesteps, n_features, n_outputs = validX.shape[1], validX.shape[2], validy.shape[1]
    
    model = Sequential()
    # Входной слой
    model.add(LSTM(100, input_shape=(n_timesteps,n_features)))
    # Скрытый слой
    for _ in range (layers_count):
        model.add(Dense(neurons_count, activation=activation))
    # Выходной слой
    model.add(Dense(n_outputs, activation=activation))
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn=create_LSTM, epochs=1, batch_size=100, verbose=0)

layers_count = [1, 2, 3, 4, 5]
neurons_count = [40, 60, 80, 100, 120]
optimizer = ['SGD']
activation = ['relu']


param_grid = dict(neurons_count=neurons_count, 
                  layers_count=layers_count, 
                  activation=activation, 
                  optimizer=optimizer)

experiment(model, param_grid)
# Out:
# Best: 0.365078 using {'activation': 'relu', 'layers_count': 2, 'neurons_count': 40, 'optimizer': 'SGD'}
# 0.273553 (0.116603) with: {'activation': 'relu', 'layers_count': 1, 'neurons_count': 40, 'optimizer': 'SGD'}
# 0.225817 (0.087444) with: {'activation': 'relu', 'layers_count': 1, 'neurons_count': 60, 'optimizer': 'SGD'}
# 0.250225 (0.075433) with: {'activation': 'relu', 'layers_count': 1, 'neurons_count': 80, 'optimizer': 'SGD'}
# 0.243118 (0.096257) with: {'activation': 'relu', 'layers_count': 1, 'neurons_count': 100, 'optimizer': 'SGD'}
# 0.257409 (0.060132) with: {'activation': 'relu', 'layers_count': 1, 'neurons_count': 120, 'optimizer': 'SGD'}
# 0.365078 (0.061481) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 40, 'optimizer': 'SGD'}
# 0.263751 (0.106451) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 60, 'optimizer': 'SGD'}
# 0.268238 (0.146216) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 80, 'optimizer': 'SGD'}
# 0.210496 (0.073715) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 100, 'optimizer': 'SGD'}
# 0.219269 (0.062046) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 120, 'optimizer': 'SGD'}
# 0.281699 (0.100031) with: {'activation': 'relu', 'layers_count': 3, 'neurons_count': 40, 'optimizer': 'SGD'}
# 0.180661 (0.049695) with: {'activation': 'relu', 'layers_count': 3, 'neurons_count': 60, 'optimizer': 'SGD'}
# 0.219753 (0.084467) with: {'activation': 'relu', 'layers_count': 3, 'neurons_count': 80, 'optimizer': 'SGD'}
# 0.229536 (0.096902) with: {'activation': 'relu', 'layers_count': 3, 'neurons_count': 100, 'optimizer': 'SGD'}
# 0.270834 (0.114622) with: {'activation': 'relu', 'layers_count': 3, 'neurons_count': 120, 'optimizer': 'SGD'}
# 0.135480 (0.005444) with: {'activation': 'relu', 'layers_count': 4, 'neurons_count': 40, 'optimizer': 'SGD'}
# 0.161573 (0.027285) with: {'activation': 'relu', 'layers_count': 4, 'neurons_count': 60, 'optimizer': 'SGD'}
# 0.163745 (0.040433) with: {'activation': 'relu', 'layers_count': 4, 'neurons_count': 80, 'optimizer': 'SGD'}
# 0.170272 (0.055647) with: {'activation': 'relu', 'layers_count': 4, 'neurons_count': 100, 'optimizer': 'SGD'}
# 0.184392 (0.048453) with: {'activation': 'relu', 'layers_count': 4, 'neurons_count': 120, 'optimizer': 'SGD'}
# 0.161053 (0.025524) with: {'activation': 'relu', 'layers_count': 5, 'neurons_count': 40, 'optimizer': 'SGD'}
# 0.169730 (0.045910) with: {'activation': 'relu', 'layers_count': 5, 'neurons_count': 60, 'optimizer': 'SGD'}
# 0.168095 (0.032705) with: {'activation': 'relu', 'layers_count': 5, 'neurons_count': 80, 'optimizer': 'SGD'}
# 0.146899 (0.013427) with: {'activation': 'relu', 'layers_count': 5, 'neurons_count': 100, 'optimizer': 'SGD'}
# 0.183351 (0.038054) with: {'activation': 'relu', 'layers_count': 5, 'neurons_count': 120, 'optimizer': 'SGD'}

# %%
model = KerasClassifier(build_fn=create_LSTM, epochs=1, batch_size=100, verbose=0)

layers_count = [2]
neurons_count = [40]
optimizer = ['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam', 'Adamax', 'Nadam']
activation = ['relu']

param_grid = dict(neurons_count=neurons_count, 
                  layers_count=layers_count, 
                  activation=activation, 
                  optimizer=optimizer)

experiment(model, param_grid)
# Out:
# Best: 0.384614 using {'activation': 'relu', 'layers_count': 2, 'neurons_count': 40, 'optimizer': 'Nadam'}
# 0.252035 (0.123983) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 40, 'optimizer': 'SGD'}
# 0.366752 (0.153756) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 40, 'optimizer': 'RMSprop'}
# 0.230676 (0.061277) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 40, 'optimizer': 'Adagrad'}
# 0.201263 (0.037152) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 40, 'optimizer': 'Adadelta'}
# 0.242711 (0.092176) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 40, 'optimizer': 'Adam'}
# 0.375382 (0.092309) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 40, 'optimizer': 'Adamax'}
# 0.384614 (0.077787) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 40, 'optimizer': 'Nadam'}

# %% [markdown]
# ### LSTM. Лучший вариант гиперпараметров: 2 скрытых слоя, 40 нейронов на них, алгоритм оптимизации - Nadam

# %% [markdown]
# GRU

# %%
def create_GRU(neurons_count=100, layers_count=1, activation='relu', optimizer='SGD'):
    n_timesteps, n_features, n_outputs = validX.shape[1], validX.shape[2], validy.shape[1]
    
    model = Sequential()
    # Входной слой
    model.add(GRU(100, input_shape=(n_timesteps,n_features)))
    # Скрытый слой
    for _ in range (layers_count):
        model.add(Dense(neurons_count, activation=activation))
    # Выходной слой
    model.add(Dense(n_outputs, activation=activation))
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn=create_GRU, epochs=1, batch_size=100, verbose=0)

layers_count = [1, 2, 3, 4, 5]
neurons_count = [40, 60, 80, 100, 120]
optimizer = ['SGD']
activation = ['relu']

param_grid = dict(neurons_count=neurons_count, 
                  layers_count=layers_count, 
                  activation=activation, 
                  optimizer=optimizer)

experiment(model, param_grid)
# Out:
# Best: 0.303751 using {'activation': 'relu', 'layers_count': 3, 'neurons_count': 60, 'optimizer': 'SGD'}
# 0.219728 (0.149893) with: {'activation': 'relu', 'layers_count': 1, 'neurons_count': 40, 'optimizer': 'SGD'}
# 0.234983 (0.133717) with: {'activation': 'relu', 'layers_count': 1, 'neurons_count': 60, 'optimizer': 'SGD'}
# 0.162664 (0.033598) with: {'activation': 'relu', 'layers_count': 1, 'neurons_count': 80, 'optimizer': 'SGD'}
# 0.275942 (0.089496) with: {'activation': 'relu', 'layers_count': 1, 'neurons_count': 100, 'optimizer': 'SGD'}
# 0.237121 (0.088286) with: {'activation': 'relu', 'layers_count': 1, 'neurons_count': 120, 'optimizer': 'SGD'}
# 0.175209 (0.042302) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 40, 'optimizer': 'SGD'}
# 0.226780 (0.089368) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 60, 'optimizer': 'SGD'}
# 0.299177 (0.154798) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 80, 'optimizer': 'SGD'}
# 0.250271 (0.092966) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 100, 'optimizer': 'SGD'}
# 0.195821 (0.093576) with: {'activation': 'relu', 'layers_count': 2, 'neurons_count': 120, 'optimizer': 'SGD'}
# 0.287219 (0.128348) with: {'activation': 'relu', 'layers_count': 3, 'neurons_count': 40, 'optimizer': 'SGD'}
# 0.303751 (0.139491) with: {'activation': 'relu', 'layers_count': 3, 'neurons_count': 60, 'optimizer': 'SGD'}
# 0.192556 (0.054804) with: {'activation': 'relu', 'layers_count': 3, 'neurons_count': 80, 'optimizer': 'SGD'}
# 0.255273 (0.154219) with: {'activation': 'relu', 'layers_count': 3, 'neurons_count': 100, 'optimizer': 'SGD'}
# 0.184975 (0.052828) with: {'activation': 'relu', 'layers_count': 3, 'neurons_count': 120, 'optimizer': 'SGD'}
# 0.286062 (0.117531) with: {'activation': 'relu', 'layers_count': 4, 'neurons_count': 40, 'optimizer': 'SGD'}
# 0.148553 (0.024527) with: {'activation': 'relu', 'layers_count': 4, 'neurons_count': 60, 'optimizer': 'SGD'}
# 0.155075 (0.021756) with: {'activation': 'relu', 'layers_count': 4, 'neurons_count': 80, 'optimizer': 'SGD'}
# 0.155084 (0.026758) with: {'activation': 'relu', 'layers_count': 4, 'neurons_count': 100, 'optimizer': 'SGD'}
# 0.157797 (0.025816) with: {'activation': 'relu', 'layers_count': 4, 'neurons_count': 120, 'optimizer': 'SGD'}
# 0.166522 (0.030857) with: {'activation': 'relu', 'layers_count': 5, 'neurons_count': 40, 'optimizer': 'SGD'}
# 0.268742 (0.104457) with: {'activation': 'relu', 'layers_count': 5, 'neurons_count': 60, 'optimizer': 'SGD'}
# 0.193158 (0.043848) with: {'activation': 'relu', 'layers_count': 5, 'neurons_count': 80, 'optimizer': 'SGD'}
# 0.191565 (0.057631) with: {'activation': 'relu', 'layers_count': 5, 'neurons_count': 100, 'optimizer': 'SGD'}
# 0.168099 (0.030434) with: {'activation': 'relu', 'layers_count': 5, 'neurons_count': 120, 'optimizer': 'SGD'}

# %%
model = KerasClassifier(build_fn=create_GRU, epochs=2, batch_size=100, verbose=0)

layers_count = [3]
neurons_count = [60]
optimizer = ['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam', 'Adamax', 'Nadam']
activation = ['relu']


param_grid = dict(neurons_count=neurons_count, 
                  layers_count=layers_count, 
                  activation=activation, 
                  optimizer=optimizer)

experiment(model, param_grid)
# Out:
# Best: 0.463375 using {'activation': 'relu', 'layers_count': 3, 'neurons_count': 60, 'optimizer': 'Nadam'}
# 0.205623 (0.062595) with: {'activation': 'relu', 'layers_count': 3, 'neurons_count': 60, 'optimizer': 'SGD'}
# 0.369377 (0.182283) with: {'activation': 'relu', 'layers_count': 3, 'neurons_count': 60, 'optimizer': 'RMSprop'}
# 0.427020 (0.081613) with: {'activation': 'relu', 'layers_count': 3, 'neurons_count': 60, 'optimizer': 'Adagrad'}
# 0.142046 (0.059440) with: {'activation': 'relu', 'layers_count': 3, 'neurons_count': 60, 'optimizer': 'Adadelta'}
# 0.259574 (0.108088) with: {'activation': 'relu', 'layers_count': 3, 'neurons_count': 60, 'optimizer': 'Adam'}
# 0.374873 (0.184397) with: {'activation': 'relu', 'layers_count': 3, 'neurons_count': 60, 'optimizer': 'Adamax'}
# 0.463375 (0.166172) with: {'activation': 'relu', 'layers_count': 3, 'neurons_count': 60, 'optimizer': 'Nadam'}

# %% [markdown]
# ### GRU. Лучший вариант гиперпараметров: 3 скрытых слоя, 60 нейронов на них, алгоритм оптимизации - Nadam

# %% [markdown]
# ### Обучение и проверка точности на тестовой выборке

# %%
from tensorflow.keras import regularizers
from keras.callbacks import ReduceLROnPlateau

# %% [markdown]
# SimpleRNN. layers_count=2, neurons_count=100, optimizer=nadam, dropout_rate=0.4, regularizer=l1

# %%
n_timesteps, n_features, n_outputs = trainX.shape[1], trainX.shape[2], trainy.shape[1]
model = Sequential()
# Входной слой
model.add(SimpleRNN(100, input_shape=(n_timesteps,n_features), kernel_regularizer='l1'))
model.add(Dropout(0.4))
# Скрытый слой
for _ in range (2):
    model.add(Dense(100, activation='relu'))
# Выходной слой
model.add(Dense(n_outputs, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='Nadam', metrics=['accuracy'])

reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2,
                              patience=3, min_lr=0.001)

for _ in range(10):
    model.fit(trainX, trainy, epochs=10, batch_size=64, verbose=2, callbacks=[reduce_lr])
    _, accuracy = model.evaluate(testX, testy, batch_size=64)
    if accuracy >= 0.91:
        break
# Out:
# Epoch 1/10
# 87/87 - 5s - loss: 2.0167 - accuracy: 0.5176
# Epoch 2/10
# 87/87 - 4s - loss: 1.4008 - accuracy: 0.6306
# Epoch 3/10
# 87/87 - 4s - loss: 1.0859 - accuracy: 0.6852
# Epoch 4/10
# 87/87 - 4s - loss: 1.2219 - accuracy: 0.6422
# Epoch 5/10
# 87/87 - 4s - loss: 1.3600 - accuracy: 0.6146
# Epoch 6/10
# 87/87 - 4s - loss: 1.5780 - accuracy: 0.4527
# Epoch 7/10
# 87/87 - 4s - loss: 1.4553 - accuracy: 0.4704
# Epoch 8/10
# 87/87 - 4s - loss: 1.3851 - accuracy: 0.4913
# Epoch 9/10
# 87/87 - 4s - loss: 1.3231 - accuracy: 0.5176
# Epoch 10/10
# 87/87 - 4s - loss: 1.2109 - accuracy: 0.5769
# 47/47 [==============================] - 1s 23ms/step - loss: 1.6331 - accuracy: 0.3590
# Epoch 1/10
# 87/87 - 4s - loss: 1.4342 - accuracy: 0.4735
# Epoch 2/10
# 87/87 - 4s - loss: 1.2629 - accuracy: 0.5453
# Epoch 3/10
# 87/87 - 4s - loss: 1.1567 - accuracy: 0.6055
# Epoch 4/10
# 87/87 - 4s - loss: 1.0610 - accuracy: 0.6340
# Epoch 5/10
# 87/87 - 4s - loss: 1.0531 - accuracy: 0.6427
# Epoch 6/10
# 87/87 - 4s - loss: 2.0598 - accuracy: 0.2896
# Epoch 7/10
# 87/87 - 4s - loss: 1.6197 - accuracy: 0.3818
# Epoch 8/10
# 87/87 - 4s - loss: 1.4024 - accuracy: 0.4672
# Epoch 9/10
# 87/87 - 3s - loss: 1.3223 - accuracy: 0.5047
# Epoch 10/10
# 87/87 - 4s - loss: 1.1862 - accuracy: 0.5508
# 47/47 [==============================] - 1s 26ms/step - loss: 2.1255 - accuracy: 0.1194
# Epoch 1/10
# 87/87 - 4s - loss: 1.1853 - accuracy: 0.5522
# Epoch 2/10
# 87/87 - 5s - loss: 1.1931 - accuracy: 0.5355
# Epoch 3/10
# 87/87 - 4s - loss: 1.1690 - accuracy: 0.5488
# Epoch 4/10
# 87/87 - 5s - loss: 1.1102 - accuracy: 0.5776
# Epoch 5/10
# 87/87 - 5s - loss: 1.1198 - accuracy: 0.5805
# Epoch 6/10
# 87/87 - 4s - loss: 1.1365 - accuracy: 0.5776
# Epoch 7/10
# 87/87 - 5s - loss: 1.1495 - accuracy: 0.5718
# Epoch 8/10
# 87/87 - 4s - loss: 1.0935 - accuracy: 0.5939
# Epoch 9/10
# 87/87 - 4s - loss: 1.0604 - accuracy: 0.6188
# Epoch 10/10
# 87/87 - 4s - loss: 1.0609 - accuracy: 0.6315
# 47/47 [==============================] - 2s 32ms/step - loss: 1.2118 - accuracy: 0.5504
# Epoch 1/10
# 87/87 - 4s - loss: 0.9652 - accuracy: 0.6589
# Epoch 2/10
# 87/87 - 4s - loss: 0.9631 - accuracy: 0.6614
# Epoch 3/10
# 87/87 - 4s - loss: 0.9450 - accuracy: 0.6687
# Epoch 4/10
# 87/87 - 4s - loss: 0.9840 - accuracy: 0.6625
# Epoch 5/10
# 87/87 - 4s - loss: 0.9271 - accuracy: 0.6810
# Epoch 6/10
# 87/87 - 4s - loss: 0.9789 - accuracy: 0.6694
# Epoch 7/10
# 87/87 - 4s - loss: 0.9111 - accuracy: 0.6881
# Epoch 8/10
# 87/87 - 4s - loss: 0.8570 - accuracy: 0.7096
# Epoch 9/10
# 87/87 - 4s - loss: 0.8625 - accuracy: 0.7073
# Epoch 10/10
# 87/87 - 4s - loss: 0.8881 - accuracy: 0.6984
# 47/47 [==============================] - 2s 32ms/step - loss: 1.0781 - accuracy: 0.6244
# Epoch 1/10
# 87/87 - 5s - loss: 0.8591 - accuracy: 0.7194
# Epoch 2/10
# 87/87 - 4s - loss: 0.9604 - accuracy: 0.6959
# Epoch 3/10
# 87/87 - 4s - loss: 0.9431 - accuracy: 0.7009
# Epoch 4/10
# 87/87 - 4s - loss: 0.8854 - accuracy: 0.7209
# Epoch 5/10
# 87/87 - 4s - loss: 0.7816 - accuracy: 0.7572
# Epoch 6/10
# 87/87 - 4s - loss: 0.8450 - accuracy: 0.7398
# Epoch 7/10
# 87/87 - 4s - loss: 0.9106 - accuracy: 0.6939
# Epoch 8/10
# 87/87 - 4s - loss: 0.7742 - accuracy: 0.7508
# Epoch 9/10
# 87/87 - 4s - loss: 0.7451 - accuracy: 0.7572
# Epoch 10/10
# 87/87 - 5s - loss: 0.7096 - accuracy: 0.7738
# 47/47 [==============================] - 1s 26ms/step - loss: 1.4813 - accuracy: 0.5103
# Epoch 1/10
# 87/87 - 5s - loss: 1.0833 - accuracy: 0.6398
# Epoch 2/10
# 87/87 - 4s - loss: 0.9914 - accuracy: 0.6676
# Epoch 3/10
# 87/87 - 4s - loss: 0.7138 - accuracy: 0.7588
# Epoch 4/10
# 87/87 - 4s - loss: 1.2682 - accuracy: 0.5843
# Epoch 5/10
# 87/87 - 5s - loss: 1.0956 - accuracy: 0.6144
# Epoch 6/10
# 87/87 - 5s - loss: 0.8335 - accuracy: 0.7242
# Epoch 7/10
# 87/87 - 5s - loss: 0.8129 - accuracy: 0.7265
# Epoch 8/10
# 87/87 - 5s - loss: 0.7439 - accuracy: 0.7457
# Epoch 9/10
# 87/87 - 5s - loss: 0.6470 - accuracy: 0.7769
# Epoch 10/10
# 87/87 - 5s - loss: 0.5749 - accuracy: 0.8076
# 47/47 [==============================] - 1s 30ms/step - loss: 0.9710 - accuracy: 0.6926
# Epoch 1/10
# 87/87 - 5s - loss: 0.5139 - accuracy: 0.8326
# Epoch 2/10
# 87/87 - 3s - loss: 0.6199 - accuracy: 0.8174
# Epoch 3/10
# 87/87 - 4s - loss: 0.4778 - accuracy: 0.8493
# Epoch 4/10
# 87/87 - 4s - loss: 0.5063 - accuracy: 0.8429
# Epoch 5/10
# 87/87 - 4s - loss: 0.4545 - accuracy: 0.8665
# Epoch 6/10
# 87/87 - 4s - loss: 0.4259 - accuracy: 0.8760
# Epoch 7/10
# 87/87 - 4s - loss: 0.3834 - accuracy: 0.8990
# Epoch 8/10
# 87/87 - 5s - loss: 0.4224 - accuracy: 0.8789
# Epoch 9/10
# 87/87 - 4s - loss: 0.3754 - accuracy: 0.8999
# Epoch 10/10
# 87/87 - 4s - loss: 0.7091 - accuracy: 0.8098
# 47/47 [==============================] - 1s 31ms/step - loss: 1.6085 - accuracy: 0.3556
# Epoch 1/10
# 87/87 - 5s - loss: 1.3663 - accuracy: 0.4771
# Epoch 2/10
# 87/87 - 5s - loss: 1.2387 - accuracy: 0.5138
# Epoch 3/10
# 87/87 - 4s - loss: 1.1602 - accuracy: 0.5486
# Epoch 4/10
# 87/87 - 4s - loss: 1.1248 - accuracy: 0.5666
# Epoch 5/10
# 87/87 - 4s - loss: 1.1026 - accuracy: 0.5709
# Epoch 6/10
# 87/87 - 4s - loss: 1.1130 - accuracy: 0.5731
# Epoch 7/10
# 87/87 - 4s - loss: 1.0990 - accuracy: 0.5762
# Epoch 8/10
# 87/87 - 4s - loss: 1.5073 - accuracy: 0.4169
# Epoch 9/10
# 87/87 - 5s - loss: 1.3279 - accuracy: 0.4514
# Epoch 10/10
# 87/87 - 4s - loss: 1.2557 - accuracy: 0.4788
# 47/47 [==============================] - 1s 27ms/step - loss: 1.3709 - accuracy: 0.4306
# Epoch 1/10
# 87/87 - 5s - loss: 1.2161 - accuracy: 0.4913
# Epoch 2/10
# 87/87 - 4s - loss: 1.2009 - accuracy: 0.5109
# Epoch 3/10
# 87/87 - 4s - loss: 1.3346 - accuracy: 0.4917
# Epoch 4/10
# 87/87 - 4s - loss: 1.2936 - accuracy: 0.4944
# Epoch 5/10
# 87/87 - 4s - loss: 1.2587 - accuracy: 0.5063
# Epoch 6/10
# 87/87 - 4s - loss: 1.1773 - accuracy: 0.5374
# Epoch 7/10
# 87/87 - 5s - loss: 1.0841 - accuracy: 0.5778
# Epoch 8/10
# 87/87 - 5s - loss: 1.2340 - accuracy: 0.5223
# Epoch 9/10
# 87/87 - 4s - loss: 1.3661 - accuracy: 0.4452
# Epoch 10/10
# 87/87 - 4s - loss: 1.2765 - accuracy: 0.4757
# 47/47 [==============================] - 1s 25ms/step - loss: 1.2908 - accuracy: 0.4829
# Epoch 1/10
# 87/87 - 4s - loss: 1.2188 - accuracy: 0.5040
# Epoch 2/10
# 87/87 - 4s - loss: 1.2060 - accuracy: 0.5082
# Epoch 3/10
# 87/87 - 5s - loss: 1.2091 - accuracy: 0.5089
# Epoch 4/10
# 87/87 - 5s - loss: 1.1747 - accuracy: 0.5187
# Epoch 5/10
# 87/87 - 4s - loss: 1.1754 - accuracy: 0.5290
# Epoch 6/10
# 87/87 - 4s - loss: 1.1043 - accuracy: 0.5615
# Epoch 7/10
# 87/87 - 4s - loss: 1.0813 - accuracy: 0.5796
# Epoch 8/10
# 87/87 - 5s - loss: 1.0293 - accuracy: 0.6262
# Epoch 9/10
# 87/87 - 6s - loss: 0.9625 - accuracy: 0.6404
# Epoch 10/10
# 87/87 - 5s - loss: 1.2588 - accuracy: 0.5544
# 47/47 [==============================] - 1s 30ms/step - loss: 1.4665 - accuracy: 0.4082

# %% [markdown]
# SimpleRNN не оправдала надежд. За 100 эпох точность на тестовой выборке не достигла порогового значения

# %% [markdown]
# LSTM. layers_count=2, neurons_count=40, optimizer=nadam, dropout_rate=0.4, regularizer=l1

# %%
n_timesteps, n_features, n_outputs = trainX.shape[1], trainX.shape[2], trainy.shape[1]
model = Sequential()
# Входной слой
model.add(LSTM(100, input_shape=(n_timesteps,n_features), kernel_regularizer='l1'))
model.add(Dropout(0.4))
# Скрытый слой
for _ in range (2):
    model.add(Dense(40, activation='relu'))
# Выходной слой
model.add(Dense(n_outputs, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='Nadam', metrics=['accuracy'])

reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2,
                              patience=3, min_lr=0.001)


for _ in range(10):
    model.fit(trainX, trainy, epochs=10, batch_size=64, verbose=2, callbacks=[reduce_lr])
    _, accuracy = model.evaluate(testX, testy, batch_size=64)
    if accuracy >= 0.91:
        break
# Out:
# Epoch 1/10
# 87/87 - 11s - loss: 2.7534 - accuracy: 0.3357
# Epoch 2/10
# 87/87 - 10s - loss: 1.5158 - accuracy: 0.4554
# Epoch 3/10
# 87/87 - 10s - loss: 1.2973 - accuracy: 0.5053
# Epoch 4/10
# 87/87 - 10s - loss: 1.1853 - accuracy: 0.5413
# Epoch 5/10
# 87/87 - 9s - loss: 1.1567 - accuracy: 0.5450
# Epoch 6/10
# 87/87 - 9s - loss: 1.1091 - accuracy: 0.5716
# Epoch 7/10
# 87/87 - 10s - loss: 1.0523 - accuracy: 0.6114
# Epoch 8/10
# 87/87 - 10s - loss: 1.2271 - accuracy: 0.5593
# Epoch 9/10
# 87/87 - 10s - loss: 0.9676 - accuracy: 0.6395
# Epoch 10/10
# 87/87 - 10s - loss: 0.8144 - accuracy: 0.6841
# 47/47 [==============================] - 3s 53ms/step - loss: 1.1073 - accuracy: 0.5684
# Epoch 1/10
# 87/87 - 10s - loss: 0.7815 - accuracy: 0.7111
# Epoch 2/10
# 87/87 - 9s - loss: 0.7421 - accuracy: 0.7490
# Epoch 3/10
# 87/87 - 10s - loss: 0.5921 - accuracy: 0.7954
# Epoch 4/10
# 87/87 - 10s - loss: 0.5501 - accuracy: 0.8342
# Epoch 5/10
# 87/87 - 10s - loss: 0.5725 - accuracy: 0.8384
# Epoch 6/10
# 87/87 - 10s - loss: 0.7834 - accuracy: 0.7891
# Epoch 7/10
# 87/87 - 9s - loss: 0.6679 - accuracy: 0.7610
# Epoch 8/10
# 87/87 - 9s - loss: 0.4819 - accuracy: 0.8662
# Epoch 9/10
# 87/87 - 9s - loss: 0.3521 - accuracy: 0.9151
# Epoch 10/10
# 87/87 - 10s - loss: 0.3391 - accuracy: 0.9175
# 47/47 [==============================] - 4s 81ms/step - loss: 0.3873 - accuracy: 0.8982 2s -
# Epoch 1/10
# 87/87 - 11s - loss: 0.3272 - accuracy: 0.9251
# Epoch 2/10
# 87/87 - 10s - loss: 0.2844 - accuracy: 0.9365
# Epoch 3/10
# 87/87 - 10s - loss: 0.2572 - accuracy: 0.9416
# Epoch 4/10
# 87/87 - 9s - loss: 0.2441 - accuracy: 0.9465
# Epoch 5/10
# 87/87 - 9s - loss: 0.2973 - accuracy: 0.9318
# Epoch 6/10
# 87/87 - 9s - loss: 0.2533 - accuracy: 0.9436
# Epoch 7/10
# 87/87 - 10s - loss: 0.2283 - accuracy: 0.9480
# Epoch 8/10
# 87/87 - 11s - loss: 0.3471 - accuracy: 0.9242
# Epoch 9/10
# 87/87 - 10s - loss: 0.2817 - accuracy: 0.9371
# Epoch 10/10
# 87/87 - 10s - loss: 0.2598 - accuracy: 0.9400
# 47/47 [==============================] - 4s 78ms/step - loss: 0.3284 - accuracy: 0.9084
# Epoch 1/10
# 87/87 - 10s - loss: 0.2426 - accuracy: 0.9438
# Epoch 2/10
# 87/87 - 10s - loss: 0.3190 - accuracy: 0.9175
# Epoch 3/10
# 87/87 - 11s - loss: 0.2230 - accuracy: 0.9450
# Epoch 4/10
# 87/87 - 11s - loss: 0.2050 - accuracy: 0.9498
# Epoch 5/10
# 87/87 - 11s - loss: 0.2212 - accuracy: 0.9480
# Epoch 6/10
# 87/87 - 11s - loss: 0.2092 - accuracy: 0.9521
# Epoch 7/10
# 87/87 - 11s - loss: 0.2701 - accuracy: 0.9324
# Epoch 8/10
# 87/87 - 9s - loss: 0.3152 - accuracy: 0.9305
# Epoch 9/10
# 87/87 - 10s - loss: 0.2278 - accuracy: 0.9450
# Epoch 10/10
# 87/87 - 9s - loss: 0.2985 - accuracy: 0.9267
# 47/47 [==============================] - 4s 83ms/step - loss: 0.3808 - accuracy: 0.8839
# Epoch 1/10
# 87/87 - 10s - loss: 0.2332 - accuracy: 0.9394
# Epoch 2/10
# 87/87 - 10s - loss: 0.2216 - accuracy: 0.9418
# Epoch 3/10
# 87/87 - 10s - loss: 0.2581 - accuracy: 0.9353
# Epoch 4/10
# 87/87 - 12s - loss: 0.2789 - accuracy: 0.9349
# Epoch 5/10
# 87/87 - 12s - loss: 0.2150 - accuracy: 0.9465
# Epoch 6/10
# 87/87 - 12s - loss: 0.1959 - accuracy: 0.9539
# Epoch 7/10
# 87/87 - 10s - loss: 0.2418 - accuracy: 0.9458
# Epoch 8/10
# 87/87 - 12s - loss: 0.1915 - accuracy: 0.9550
# Epoch 9/10
# 87/87 - 10s - loss: 0.1877 - accuracy: 0.9541
# Epoch 10/10
# 87/87 - 11s - loss: 0.1793 - accuracy: 0.9581
# 47/47 [==============================] - 4s 83ms/step - loss: 0.4777 - accuracy: 0.8592
# Epoch 1/10
# 87/87 - 10s - loss: 0.2073 - accuracy: 0.9460
# Epoch 2/10
# 87/87 - 11s - loss: 0.1742 - accuracy: 0.9577
# Epoch 3/10
# 87/87 - 11s - loss: 0.1787 - accuracy: 0.9552
# Epoch 4/10
# 87/87 - 11s - loss: 0.1844 - accuracy: 0.9561
# Epoch 5/10
# 87/87 - 11s - loss: 1.5492 - accuracy: 0.6634
# Epoch 6/10
# 87/87 - 10s - loss: 0.8511 - accuracy: 0.7049
# Epoch 7/10
# 87/87 - 10s - loss: 0.5528 - accuracy: 0.8014
# Epoch 8/10
# 87/87 - 10s - loss: 0.4506 - accuracy: 0.8215
# Epoch 9/10
# 87/87 - 10s - loss: 0.4365 - accuracy: 0.8313
# Epoch 10/10
# 87/87 - 10s - loss: 0.4237 - accuracy: 0.8406
# 47/47 [==============================] - 4s 83ms/step - loss: 0.5661 - accuracy: 0.7903
# Epoch 1/10
# 87/87 - 11s - loss: 0.3891 - accuracy: 0.8604
# Epoch 2/10
# 87/87 - 11s - loss: 0.3774 - accuracy: 0.8689
# Epoch 3/10
# 87/87 - 11s - loss: 0.3487 - accuracy: 0.8872
# Epoch 4/10
# 87/87 - 11s - loss: 0.2682 - accuracy: 0.9320
# Epoch 5/10
# 87/87 - 11s - loss: 0.2437 - accuracy: 0.9423
# Epoch 6/10
# 87/87 - 11s - loss: 0.7705 - accuracy: 0.8059
# Epoch 7/10
# 87/87 - 10s - loss: 0.7219 - accuracy: 0.7682
# Epoch 8/10
# 87/87 - 10s - loss: 0.5436 - accuracy: 0.8076
# Epoch 9/10
# 87/87 - 10s - loss: 0.4750 - accuracy: 0.8263
# Epoch 10/10
# 87/87 - 10s - loss: 0.4132 - accuracy: 0.8634
# 47/47 [==============================] - 4s 85ms/step - loss: 0.5261 - accuracy: 0.8463
# Epoch 1/10
# 87/87 - 10s - loss: 0.3510 - accuracy: 0.9044
# Epoch 2/10
# 87/87 - 11s - loss: 0.3258 - accuracy: 0.9153
# Epoch 3/10
# 87/87 - 10s - loss: 0.3047 - accuracy: 0.9218
# Epoch 4/10
# 87/87 - 10s - loss: 0.2867 - accuracy: 0.9351
# Epoch 5/10
# 87/87 - 10s - loss: 0.5624 - accuracy: 0.8121
# Epoch 6/10
# 87/87 - 11s - loss: 0.3765 - accuracy: 0.8845
# Epoch 7/10
# 87/87 - 9s - loss: 0.3104 - accuracy: 0.9155
# Epoch 8/10
# 87/87 - 11s - loss: 0.2606 - accuracy: 0.9298
# Epoch 9/10
# 87/87 - 10s - loss: 0.4863 - accuracy: 0.8654
# Epoch 10/10
# 87/87 - 10s - loss: 0.3040 - accuracy: 0.9135
# 47/47 [==============================] - 4s 81ms/step - loss: 0.3957 - accuracy: 0.8924
# Epoch 1/10
# 87/87 - 10s - loss: 0.2621 - accuracy: 0.9271
# Epoch 2/10
# 87/87 - 10s - loss: 0.2433 - accuracy: 0.9347
# Epoch 3/10
# 87/87 - 10s - loss: 0.2263 - accuracy: 0.9389
# Epoch 4/10
# 87/87 - 10s - loss: 0.2062 - accuracy: 0.9450
# Epoch 5/10
# 87/87 - 10s - loss: 0.2149 - accuracy: 0.9440
# Epoch 6/10
# 87/87 - 10s - loss: 0.2183 - accuracy: 0.9411
# Epoch 7/10
# 87/87 - 10s - loss: 0.1892 - accuracy: 0.9496
# Epoch 8/10
# 87/87 - 10s - loss: 0.2054 - accuracy: 0.9467
# Epoch 9/10
# 87/87 - 10s - loss: 0.1791 - accuracy: 0.9554
# Epoch 10/10
# 87/87 - 10s - loss: 0.1895 - accuracy: 0.9523
# 47/47 [==============================] - 4s 82ms/step - loss: 0.2859 - accuracy: 0.9104 1s - loss: 0.4045 - accura - ETA: 1s - l

# %% [markdown]
# Модель LSTM достигла порогового значения точности на тестовой выборке.

# %% [markdown]
# GRU. layers_count=3, neurons_count=60, optimizer=nadam, dropout_rate=0.4, regularizer=l1

# %%
n_timesteps, n_features, n_outputs = trainX.shape[1], trainX.shape[2], trainy.shape[1]
model = Sequential()
# Входной слой
model.add(GRU(100, input_shape=(n_timesteps,n_features), kernel_regularizer='l1'))
model.add(Dropout(0.4))
# Скрытый слой
for _ in range (3):
    model.add(Dense(60, activation='relu'))
# Выходной слой
model.add(Dense(n_outputs, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='Nadam', metrics=['accuracy'])

reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2,
                              patience=3, min_lr=0.001)


for _ in range(10):
    model.fit(trainX, trainy, epochs=10, batch_size=64, verbose=2, callbacks=[reduce_lr])
    _, accuracy = model.evaluate(testX, testy, batch_size=64)
    if accuracy >= 0.91:
        break
# Out:
# Epoch 1/10
# 87/87 - 9s - loss: 2.3839 - accuracy: 0.4565
# Epoch 2/10
# 87/87 - 10s - loss: 1.2674 - accuracy: 0.5225
# Epoch 3/10
# 87/87 - 8s - loss: 1.1431 - accuracy: 0.5461
# Epoch 4/10
# 87/87 - 8s - loss: 1.0860 - accuracy: 0.5608
# Epoch 5/10
# 87/87 - 8s - loss: 1.0379 - accuracy: 0.5903
# Epoch 6/10
# 87/87 - 9s - loss: 0.9936 - accuracy: 0.6453
# Epoch 7/10
# 87/87 - 8s - loss: 1.4719 - accuracy: 0.4862
# Epoch 8/10
# 87/87 - 8s - loss: 1.4193 - accuracy: 0.4786
# Epoch 9/10
# 87/87 - 9s - loss: 1.2878 - accuracy: 0.5205
# Epoch 10/10
# 87/87 - 10s - loss: 1.2169 - accuracy: 0.5413
# 47/47 [==============================] - 2s 38ms/step - loss: 1.2752 - accuracy: 0.4849
# Epoch 1/10
# 87/87 - 11s - loss: 1.1955 - accuracy: 0.5515
# Epoch 2/10
# 87/87 - 12s - loss: 1.2075 - accuracy: 0.5426
# Epoch 3/10
# 87/87 - 11s - loss: 1.4414 - accuracy: 0.4648
# Epoch 4/10
# 87/87 - 10s - loss: 1.3850 - accuracy: 0.4159
# Epoch 5/10
# 87/87 - 11s - loss: 1.3561 - accuracy: 0.4189
# Epoch 6/10
# 87/87 - 14s - loss: 1.3358 - accuracy: 0.4324
# Epoch 7/10
# 87/87 - 14s - loss: 1.4985 - accuracy: 0.4269
# Epoch 8/10
# 87/87 - 13s - loss: 1.3114 - accuracy: 0.4975
# Epoch 9/10
# 87/87 - 14s - loss: 1.1959 - accuracy: 0.5437
# Epoch 10/10
# 87/87 - 10s - loss: 1.1342 - accuracy: 0.5646
# 47/47 [==============================] - 3s 59ms/step - loss: 1.2478 - accuracy: 0.5175
# Epoch 1/10
# 87/87 - 8s - loss: 1.0483 - accuracy: 0.6016
# Epoch 2/10
# 87/87 - 9s - loss: 1.0167 - accuracy: 0.6155
# Epoch 3/10
# 87/87 - 8s - loss: 0.9440 - accuracy: 0.6358
# Epoch 4/10
# 87/87 - 8s - loss: 0.9296 - accuracy: 0.6362
# Epoch 5/10
# 87/87 - 8s - loss: 0.9225 - accuracy: 0.6502
# Epoch 6/10
# 87/87 - 8s - loss: 1.0046 - accuracy: 0.6253
# Epoch 7/10
# 87/87 - 10s - loss: 1.0884 - accuracy: 0.6037
# Epoch 8/10
# 87/87 - 10s - loss: 0.9909 - accuracy: 0.6282
# Epoch 9/10
# 87/87 - 9s - loss: 0.9615 - accuracy: 0.6251
# Epoch 10/10
# 87/87 - 10s - loss: 0.9112 - accuracy: 0.6357
# 47/47 [==============================] - 3s 64ms/step - loss: 1.0279 - accuracy: 0.6077
# Epoch 1/10
# 87/87 - 13s - loss: 0.8906 - accuracy: 0.6462
# Epoch 2/10
# 87/87 - 9s - loss: 0.8878 - accuracy: 0.6387
# Epoch 3/10
# 87/87 - 10s - loss: 0.8721 - accuracy: 0.6496
# Epoch 4/10
# 87/87 - 10s - loss: 0.8582 - accuracy: 0.6630
# Epoch 5/10
# 87/87 - 10s - loss: 0.8652 - accuracy: 0.6561
# Epoch 6/10
# 87/87 - 10s - loss: 0.8216 - accuracy: 0.6763
# Epoch 7/10
# 87/87 - 10s - loss: 0.8229 - accuracy: 0.6668
# Epoch 8/10
# 87/87 - 12s - loss: 0.8146 - accuracy: 0.6719
# Epoch 9/10
# 87/87 - 14s - loss: 0.8078 - accuracy: 0.6772
# Epoch 10/10
# 87/87 - 14s - loss: 0.8068 - accuracy: 0.6808
# 47/47 [==============================] - 3s 61ms/step - loss: 0.9318 - accuracy: 0.6216
# Epoch 1/10
# 87/87 - 14s - loss: 0.8140 - accuracy: 0.6790
# Epoch 2/10
# 87/87 - 13s - loss: 0.8012 - accuracy: 0.6872
# Epoch 3/10
# 87/87 - 8s - loss: 0.9638 - accuracy: 0.6547
# Epoch 4/10
# 87/87 - 9s - loss: 0.9926 - accuracy: 0.6540
# Epoch 5/10
# 87/87 - 8s - loss: 0.8854 - accuracy: 0.6748
# Epoch 6/10
# 87/87 - 8s - loss: 0.8321 - accuracy: 0.6863
# Epoch 7/10
# 87/87 - 8s - loss: 0.8841 - accuracy: 0.6768
# Epoch 8/10
# 87/87 - 8s - loss: 0.8145 - accuracy: 0.6957
# Epoch 9/10
# 87/87 - 8s - loss: 0.9557 - accuracy: 0.6592
# Epoch 10/10
# 87/87 - 8s - loss: 1.3641 - accuracy: 0.5589
# 47/47 [==============================] - 3s 62ms/step - loss: 1.9762 - accuracy: 0.3570
# Epoch 1/10
# 87/87 - 10s - loss: 1.6864 - accuracy: 0.4650
# Epoch 2/10
# 87/87 - 9s - loss: 1.3842 - accuracy: 0.5727
# Epoch 3/10
# 87/87 - 14s - loss: 1.2597 - accuracy: 0.5985
# Epoch 4/10
# 87/87 - 13s - loss: 1.1902 - accuracy: 0.6226
# Epoch 5/10
# 87/87 - 13s - loss: 1.1606 - accuracy: 0.6253
# Epoch 6/10
# 87/87 - 14s - loss: 1.1037 - accuracy: 0.6355
# Epoch 7/10
# 87/87 - 14s - loss: 1.0398 - accuracy: 0.6483
# Epoch 8/10
# 87/87 - 13s - loss: 0.9900 - accuracy: 0.6590
# Epoch 9/10
# 87/87 - 13s - loss: 0.9308 - accuracy: 0.6710
# Epoch 10/10
# 87/87 - 14s - loss: 0.8934 - accuracy: 0.6868
# 47/47 [==============================] - 3s 63ms/step - loss: 1.0314 - accuracy: 0.6155
# Epoch 1/10
# 87/87 - 15s - loss: 0.8807 - accuracy: 0.6930
# Epoch 2/10
# 87/87 - 14s - loss: 0.9568 - accuracy: 0.6868
# Epoch 3/10
# 87/87 - 10s - loss: 0.8733 - accuracy: 0.7115
# Epoch 4/10
# 87/87 - 11s - loss: 0.8179 - accuracy: 0.7310
# Epoch 5/10
# 87/87 - 11s - loss: 0.7896 - accuracy: 0.7323
# Epoch 6/10
# 87/87 - 10s - loss: 0.7677 - accuracy: 0.7396
# Epoch 7/10
# 87/87 - 10s - loss: 0.7324 - accuracy: 0.7546
# Epoch 8/10
# 87/87 - 8s - loss: 0.7177 - accuracy: 0.7524
# Epoch 9/10
# 87/87 - 8s - loss: 0.8123 - accuracy: 0.7358
# Epoch 10/10
# 87/87 - 9s - loss: 0.7073 - accuracy: 0.7760
# 47/47 [==============================] - 3s 58ms/step - loss: 0.7713 - accuracy: 0.7391
# Epoch 1/10
# 87/87 - 9s - loss: 0.6686 - accuracy: 0.7746
# Epoch 2/10
# 87/87 - 8s - loss: 0.6287 - accuracy: 0.7907
# Epoch 3/10
# 87/87 - 8s - loss: 0.5996 - accuracy: 0.8036
# Epoch 4/10
# 87/87 - 8s - loss: 0.5721 - accuracy: 0.8110
# Epoch 5/10
# 87/87 - 9s - loss: 0.5477 - accuracy: 0.8199
# Epoch 6/10
# 87/87 - 10s - loss: 0.5298 - accuracy: 0.8313
# Epoch 7/10
# 87/87 - 8s - loss: 0.5244 - accuracy: 0.8205
# Epoch 8/10
# 87/87 - 9s - loss: 0.4978 - accuracy: 0.8351
# Epoch 9/10
# 87/87 - 8s - loss: 0.4836 - accuracy: 0.8455
# Epoch 10/10
# 87/87 - 8s - loss: 0.4655 - accuracy: 0.8555
# 47/47 [==============================] - 3s 61ms/step - loss: 0.5616 - accuracy: 0.8578
# Epoch 1/10
# 87/87 - 9s - loss: 0.4439 - accuracy: 0.8689
# Epoch 2/10
# 87/87 - 9s - loss: 0.4143 - accuracy: 0.8905
# Epoch 3/10
# 87/87 - 9s - loss: 0.3939 - accuracy: 0.8970
# Epoch 4/10
# 87/87 - 9s - loss: 0.3706 - accuracy: 0.9090
# Epoch 5/10
# 87/87 - 10s - loss: 0.3490 - accuracy: 0.9155
# Epoch 6/10
# 87/87 - 9s - loss: 0.3235 - accuracy: 0.9275
# Epoch 7/10
# 87/87 - 8s - loss: 0.3278 - accuracy: 0.9246
# Epoch 8/10
# 87/87 - 8s - loss: 0.3011 - accuracy: 0.9347
# Epoch 9/10
# 87/87 - 10s - loss: 0.2933 - accuracy: 0.9324
# Epoch 10/10
# 87/87 - 8s - loss: 0.2806 - accuracy: 0.9373
# 47/47 [==============================] - 3s 61ms/step - loss: 0.4479 - accuracy: 0.8785
# Epoch 1/10
# 87/87 - 9s - loss: 0.2782 - accuracy: 0.9363
# Epoch 2/10
# 87/87 - 9s - loss: 0.2658 - accuracy: 0.9391
# Epoch 3/10
# 87/87 - 9s - loss: 0.2595 - accuracy: 0.9394
# Epoch 4/10
# 87/87 - 8s - loss: 0.2578 - accuracy: 0.9418
# Epoch 5/10
# 87/87 - 9s - loss: 0.2606 - accuracy: 0.9411
# Epoch 6/10
# 87/87 - 9s - loss: 0.2542 - accuracy: 0.9412
# Epoch 7/10
# 87/87 - 9s - loss: 0.2387 - accuracy: 0.9445
# Epoch 8/10
# 87/87 - 11s - loss: 0.2376 - accuracy: 0.9460
# Epoch 9/10
# 87/87 - 11s - loss: 0.2394 - accuracy: 0.9469
# Epoch 10/10
# 87/87 - 10s - loss: 0.2247 - accuracy: 0.9463
# 47/47 [==============================] - 3s 58ms/step - loss: 0.4132 - accuracy: 0.8945

# %% [markdown]
# Модель на основе GRU почти достигла порогового значения за 100 эпох, но так и не превзошла его.

# %% [markdown]
# Запуск модели LSTM без early stopping для замера конечной точности. 150 эпох

# %%
n_timesteps, n_features, n_outputs = trainX.shape[1], trainX.shape[2], trainy.shape[1]
model = Sequential()
# Входной слой
model.add(LSTM(100, input_shape=(n_timesteps,n_features), kernel_regularizer='l1'))
model.add(Dropout(0.4))
# Скрытый слой
for _ in range (2):
    model.add(Dense(40, activation='relu'))
# Выходной слой
model.add(Dense(n_outputs, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='Nadam', metrics=['accuracy'])

reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2,
                              patience=3, min_lr=0.001)


for _ in range(15):
    model.fit(trainX, trainy, epochs=10, batch_size=64, verbose=2, callbacks=[reduce_lr])
    _, accuracy = model.evaluate(testX, testy, batch_size=64)
# Out:
# Epoch 1/10
# 87/87 - 10s - loss: 2.7388 - accuracy: 0.3197
# Epoch 2/10
# 87/87 - 8s - loss: 1.4844 - accuracy: 0.3698
# Epoch 3/10
# 87/87 - 9s - loss: 1.4049 - accuracy: 0.3921
# Epoch 4/10
# 87/87 - 10s - loss: 1.3668 - accuracy: 0.4246
# Epoch 5/10
# 87/87 - 9s - loss: 1.5299 - accuracy: 0.4008
# Epoch 6/10
# 87/87 - 10s - loss: 1.3799 - accuracy: 0.4287
# Epoch 7/10
# 87/87 - 9s - loss: 1.1842 - accuracy: 0.5317
# Epoch 8/10
# 87/87 - 9s - loss: 1.0009 - accuracy: 0.6025
# Epoch 9/10
# 87/87 - 9s - loss: 0.7837 - accuracy: 0.6993
# Epoch 10/10
# 87/87 - 10s - loss: 0.6708 - accuracy: 0.7490
# 47/47 [==============================] - 4s 81ms/step - loss: 0.8972 - accuracy: 0.6407
# Epoch 1/10
# 87/87 - 10s - loss: 0.6166 - accuracy: 0.7855
# Epoch 2/10
# 87/87 - 10s - loss: 0.5325 - accuracy: 0.8255
# Epoch 3/10
# 87/87 - 10s - loss: 0.4893 - accuracy: 0.8509
# Epoch 4/10
# 87/87 - 10s - loss: 0.5385 - accuracy: 0.8484
# Epoch 5/10
# 87/87 - 10s - loss: 0.5221 - accuracy: 0.8429
# Epoch 6/10
# 87/87 - 10s - loss: 0.4280 - accuracy: 0.8803
# Epoch 7/10
# 87/87 - 10s - loss: 0.3529 - accuracy: 0.9111
# Epoch 8/10
# 87/87 - 10s - loss: 0.3167 - accuracy: 0.9242
# Epoch 9/10
# 87/87 - 10s - loss: 0.3028 - accuracy: 0.9275
# Epoch 10/10
# 87/87 - 10s - loss: 0.2918 - accuracy: 0.9300
# 47/47 [==============================] - 4s 89ms/step - loss: 0.6433 - accuracy: 0.7923
# Epoch 1/10
# 87/87 - 11s - loss: 0.4131 - accuracy: 0.8995
# Epoch 2/10
# 87/87 - 10s - loss: 0.4741 - accuracy: 0.8663
# Epoch 3/10
# 87/87 - 11s - loss: 0.2868 - accuracy: 0.9322
# Epoch 4/10
# 87/87 - 10s - loss: 0.2707 - accuracy: 0.9309
# Epoch 5/10
# 87/87 - 11s - loss: 0.2689 - accuracy: 0.9362
# Epoch 6/10
# 87/87 - 10s - loss: 0.3546 - accuracy: 0.9153
# Epoch 7/10
# 87/87 - 11s - loss: 0.2624 - accuracy: 0.9324
# Epoch 8/10
# 87/87 - 10s - loss: 0.2643 - accuracy: 0.9331
# Epoch 9/10
# 87/87 - 10s - loss: 0.2356 - accuracy: 0.9407
# Epoch 10/10
# 87/87 - 10s - loss: 0.2840 - accuracy: 0.9242
# 47/47 [==============================] - 4s 89ms/step - loss: 0.3683 - accuracy: 0.8958
# Epoch 1/10
# 87/87 - 10s - loss: 0.2590 - accuracy: 0.9338
# Epoch 2/10
# 87/87 - 11s - loss: 0.2191 - accuracy: 0.9452
# Epoch 3/10
# 87/87 - 11s - loss: 0.2076 - accuracy: 0.9474
# Epoch 4/10
# 87/87 - 11s - loss: 0.2087 - accuracy: 0.9440
# Epoch 5/10
# 87/87 - 11s - loss: 0.2640 - accuracy: 0.9367
# Epoch 6/10
# 87/87 - 11s - loss: 0.2251 - accuracy: 0.9423
# Epoch 7/10
# 87/87 - 13s - loss: 0.2213 - accuracy: 0.9440
# Epoch 8/10
# 87/87 - 11s - loss: 0.2092 - accuracy: 0.9445
# Epoch 9/10
# 87/87 - 11s - loss: 0.2390 - accuracy: 0.9400
# Epoch 10/10
# 87/87 - 10s - loss: 0.2415 - accuracy: 0.9380
# 47/47 [==============================] - 4s 90ms/step - loss: 0.3489 - accuracy: 0.9040
# Epoch 1/10
# 87/87 - 11s - loss: 0.2110 - accuracy: 0.9449
# Epoch 2/10
# 87/87 - 10s - loss: 0.2029 - accuracy: 0.9465
# Epoch 3/10
# 87/87 - 10s - loss: 0.3294 - accuracy: 0.9189
# Epoch 4/10
# 87/87 - 10s - loss: 0.4009 - accuracy: 0.8945
# Epoch 5/10
# 87/87 - 10s - loss: 0.3579 - accuracy: 0.9048
# Epoch 6/10
# 87/87 - 10s - loss: 0.4463 - accuracy: 0.8682
# Epoch 7/10
# 87/87 - 10s - loss: 0.3426 - accuracy: 0.9082
# Epoch 8/10
# 87/87 - 10s - loss: 0.2503 - accuracy: 0.9320
# Epoch 9/10
# 87/87 - 10s - loss: 0.2359 - accuracy: 0.9333
# Epoch 10/10
# 87/87 - 10s - loss: 0.4020 - accuracy: 0.9119
# 47/47 [==============================] - 4s 89ms/step - loss: 0.5879 - accuracy: 0.8707
# Epoch 1/10
# 87/87 - 10s - loss: 0.2358 - accuracy: 0.9369
# Epoch 2/10
# 87/87 - 10s - loss: 0.2474 - accuracy: 0.9349
# Epoch 3/10
# 87/87 - 10s - loss: 0.2085 - accuracy: 0.9447
# Epoch 4/10
# 87/87 - 11s - loss: 0.2016 - accuracy: 0.9463
# Epoch 5/10
# 87/87 - 10s - loss: 0.3226 - accuracy: 0.9084
# Epoch 6/10
# 87/87 - 10s - loss: 0.2213 - accuracy: 0.9447
# Epoch 7/10
# 87/87 - 10s - loss: 0.2765 - accuracy: 0.9273
# Epoch 8/10
# 87/87 - 11s - loss: 0.2043 - accuracy: 0.9463
# Epoch 9/10
# 87/87 - 10s - loss: 0.2300 - accuracy: 0.9389
# Epoch 10/10
# 87/87 - 11s - loss: 0.2662 - accuracy: 0.9322
# 47/47 [==============================] - 4s 87ms/step - loss: 1.5510 - accuracy: 0.7550
# Epoch 1/10
# 87/87 - 10s - loss: 0.2138 - accuracy: 0.9425
# Epoch 2/10
# 87/87 - 10s - loss: 0.1862 - accuracy: 0.9510
# Epoch 3/10
# 87/87 - 10s - loss: 0.1832 - accuracy: 0.9481
# Epoch 4/10
# 87/87 - 10s - loss: 0.2055 - accuracy: 0.9458
# Epoch 5/10
# 87/87 - 11s - loss: 0.1765 - accuracy: 0.9510
# Epoch 6/10
# 87/87 - 10s - loss: 0.1688 - accuracy: 0.9547
# Epoch 7/10
# 87/87 - 10s - loss: 0.1809 - accuracy: 0.9505
# Epoch 8/10
# 87/87 - 10s - loss: 0.2122 - accuracy: 0.9409
# Epoch 9/10
# 87/87 - 12s - loss: 0.1804 - accuracy: 0.9512
# Epoch 10/10
# 87/87 - 10s - loss: 0.1776 - accuracy: 0.9499
# 47/47 [==============================] - 3s 68ms/step - loss: 0.4541 - accuracy: 0.8907 0s - los
# Epoch 1/10
# 87/87 - 11s - loss: 0.1905 - accuracy: 0.9487
# Epoch 2/10
# 87/87 - 10s - loss: 0.1649 - accuracy: 0.9528
# Epoch 3/10
# 87/87 - 10s - loss: 0.2010 - accuracy: 0.9431
# Epoch 4/10
# 87/87 - 10s - loss: 0.2909 - accuracy: 0.9218
# Epoch 5/10
# 87/87 - 10s - loss: 0.1810 - accuracy: 0.9496
# Epoch 6/10
# 87/87 - 10s - loss: 0.1862 - accuracy: 0.9492
# Epoch 7/10
# 87/87 - 10s - loss: 0.1671 - accuracy: 0.9552
# Epoch 8/10
# 87/87 - 10s - loss: 0.2490 - accuracy: 0.9340
# Epoch 9/10
# 87/87 - 10s - loss: 0.3146 - accuracy: 0.9316
# Epoch 10/10
# 87/87 - 10s - loss: 0.3144 - accuracy: 0.9182
# 47/47 [==============================] - 3s 69ms/step - loss: 0.3113 - accuracy: 0.9077
# Epoch 1/10
# 87/87 - 10s - loss: 0.2419 - accuracy: 0.9432
# Epoch 2/10
# 87/87 - 11s - loss: 0.2387 - accuracy: 0.9425
# Epoch 3/10
# 87/87 - 10s - loss: 0.2049 - accuracy: 0.9485
# Epoch 4/10
# 87/87 - 10s - loss: 0.1941 - accuracy: 0.9523
# Epoch 5/10
# 87/87 - 10s - loss: 0.1773 - accuracy: 0.9518
# Epoch 6/10
# 87/87 - 10s - loss: 0.1678 - accuracy: 0.9547
# Epoch 7/10
# 87/87 - 10s - loss: 0.1850 - accuracy: 0.9510
# Epoch 8/10
# 87/87 - 11s - loss: 0.1723 - accuracy: 0.9534
# Epoch 9/10
# 87/87 - 10s - loss: 0.1881 - accuracy: 0.9474
# Epoch 10/10
# 87/87 - 10s - loss: 0.1657 - accuracy: 0.9530
# 47/47 [==============================] - 4s 86ms/step - loss: 0.3107 - accuracy: 0.9074
# Epoch 1/10
# 87/87 - 11s - loss: 0.1604 - accuracy: 0.9536
# Epoch 2/10
# 87/87 - 10s - loss: 0.1599 - accuracy: 0.9538
# Epoch 3/10
# 87/87 - 11s - loss: 0.2291 - accuracy: 0.9362
# Epoch 4/10
# 87/87 - 12s - loss: 0.1809 - accuracy: 0.9512
# Epoch 5/10
# 87/87 - 16s - loss: 0.1824 - accuracy: 0.9519
# Epoch 6/10
# 87/87 - 14s - loss: 0.2499 - accuracy: 0.9403
# Epoch 7/10
# 87/87 - 16s - loss: 0.1737 - accuracy: 0.9523
# Epoch 8/10
# 87/87 - 16s - loss: 0.1799 - accuracy: 0.9509
# Epoch 9/10
# 87/87 - 16s - loss: 0.1624 - accuracy: 0.9534
# Epoch 10/10
# 87/87 - 14s - loss: 0.4090 - accuracy: 0.9159
# 47/47 [==============================] - 4s 84ms/step - loss: 0.3226 - accuracy: 0.9060
# Epoch 1/10
# 87/87 - 16s - loss: 0.1804 - accuracy: 0.9528
# Epoch 2/10
# 87/87 - 16s - loss: 0.2340 - accuracy: 0.9336
# Epoch 3/10
# 87/87 - 16s - loss: 0.1762 - accuracy: 0.9514
# Epoch 4/10
# 87/87 - 16s - loss: 0.1663 - accuracy: 0.9548
# Epoch 5/10
# 87/87 - 16s - loss: 0.1699 - accuracy: 0.9498
# Epoch 6/10
# 87/87 - 16s - loss: 0.1584 - accuracy: 0.9547
# Epoch 7/10
# 87/87 - 15s - loss: 0.1598 - accuracy: 0.9547
# Epoch 8/10
# 87/87 - 15s - loss: 0.1582 - accuracy: 0.9548
# Epoch 9/10
# 87/87 - 16s - loss: 0.1710 - accuracy: 0.9532
# Epoch 10/10
# 87/87 - 16s - loss: 0.1864 - accuracy: 0.9490
# 47/47 [==============================] - 4s 88ms/step - loss: 0.2866 - accuracy: 0.9186
# Epoch 1/10
# 87/87 - 16s - loss: 0.1517 - accuracy: 0.9590
# Epoch 2/10
# 87/87 - 15s - loss: 0.1480 - accuracy: 0.9581
# Epoch 3/10
# 87/87 - 16s - loss: 0.1470 - accuracy: 0.9554
# Epoch 4/10
# 87/87 - 16s - loss: 0.1466 - accuracy: 0.9574
# Epoch 5/10
# 87/87 - 14s - loss: 0.1643 - accuracy: 0.9536
# Epoch 6/10
# 87/87 - 14s - loss: 0.3152 - accuracy: 0.9291
# Epoch 7/10
# 87/87 - 16s - loss: 0.2784 - accuracy: 0.9331
# Epoch 8/10
# 87/87 - 16s - loss: 0.2094 - accuracy: 0.9476
# Epoch 9/10
# 87/87 - 16s - loss: 0.1778 - accuracy: 0.9510
# Epoch 10/10
# 87/87 - 16s - loss: 0.1973 - accuracy: 0.9458
# 47/47 [==============================] - 4s 87ms/step - loss: 0.4187 - accuracy: 0.8711
# Epoch 1/10
# 87/87 - 15s - loss: 0.2017 - accuracy: 0.9481
# Epoch 2/10
# 87/87 - 15s - loss: 0.1851 - accuracy: 0.9501
# Epoch 3/10
# 87/87 - 15s - loss: 0.1767 - accuracy: 0.9503
# Epoch 4/10
# 87/87 - 15s - loss: 0.1636 - accuracy: 0.9557
# Epoch 5/10
# 87/87 - 14s - loss: 0.1578 - accuracy: 0.9541
# Epoch 6/10
# 87/87 - 16s - loss: 0.2673 - accuracy: 0.9278
# Epoch 7/10
# 87/87 - 16s - loss: 0.1861 - accuracy: 0.9461
# Epoch 8/10
# 87/87 - 16s - loss: 0.1726 - accuracy: 0.9505
# Epoch 9/10
# 87/87 - 16s - loss: 0.3404 - accuracy: 0.9249
# Epoch 10/10
# 87/87 - 15s - loss: 1.2850 - accuracy: 0.6224
# 47/47 [==============================] - 4s 90ms/step - loss: 1.7407 - accuracy: 0.5019  - ETA: 0s - loss: 1.7710 - ac
# Epoch 1/10
# 87/87 - 16s - loss: 1.7610 - accuracy: 0.3683
# Epoch 2/10
# 87/87 - 16s - loss: 1.4483 - accuracy: 0.4496
# Epoch 3/10
# 87/87 - 16s - loss: 1.3957 - accuracy: 0.4623
# Epoch 4/10
# 87/87 - 16s - loss: 1.2141 - accuracy: 0.5403
# Epoch 5/10
# 87/87 - 16s - loss: 1.0736 - accuracy: 0.5985
# Epoch 6/10
# 87/87 - 16s - loss: 0.8519 - accuracy: 0.6476
# Epoch 7/10
# 87/87 - 15s - loss: 0.7635 - accuracy: 0.6870
# Epoch 8/10
# 87/87 - 14s - loss: 0.7939 - accuracy: 0.6950
# Epoch 9/10
# 87/87 - 16s - loss: 0.6100 - accuracy: 0.7731
# Epoch 10/10
# 87/87 - 16s - loss: 0.5238 - accuracy: 0.8201
# 47/47 [==============================] - 4s 87ms/step - loss: 0.6435 - accuracy: 0.8127
# Epoch 1/10
# 87/87 - 16s - loss: 0.4490 - accuracy: 0.8604
# Epoch 2/10
# 87/87 - 16s - loss: 0.3956 - accuracy: 0.8859
# Epoch 3/10
# 87/87 - 16s - loss: 0.4951 - accuracy: 0.8357
# Epoch 4/10
# 87/87 - 16s - loss: 0.3552 - accuracy: 0.9006
# Epoch 5/10
# 87/87 - 15s - loss: 0.3445 - accuracy: 0.9182
# Epoch 6/10
# 87/87 - 16s - loss: 0.3413 - accuracy: 0.9111
# Epoch 7/10
# 87/87 - 16s - loss: 0.2682 - accuracy: 0.9322
# Epoch 8/10
# 87/87 - 17s - loss: 0.2766 - accuracy: 0.9327
# Epoch 9/10
# 87/87 - 16s - loss: 0.2545 - accuracy: 0.9342
# Epoch 10/10
# 87/87 - 16s - loss: 0.2734 - accuracy: 0.9302
# 47/47 [==============================] - 4s 90ms/step - loss: 0.6207 - accuracy: 0.8480

# %% [markdown]
# Максимальное значение точности для данной модели которое было зафиксированно равно 0.9186
